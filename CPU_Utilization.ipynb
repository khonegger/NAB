# %%
import scipy as scipy
import numpy as np
import pandas as pd
import json
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Function: plots time series for CPU Utilization, takes csv file name as input

def plotCPUUtilizationSeries(data_fname,title):
    
    base_path = 'data/realAWSCloudwatch/'

    # Read NAB data into pandas dataframe
    cpu_data = pd.read_csv(base_path + data_fname)
    cpu_util = cpu_data['value']

    # Plot tweet volume time series, highlight anomalies
    plt.figure(figsize=[20,10])

    plt.plot(cpu_util, zorder=1)
    plt.hold
    plt.title(title)
    plt.xlabel('sample index')
    plt.ylabel('CPU Utilization')

# %%
fnames = ['5f5533.csv','24ae8d.csv','53ea38.csv','77c1ca.csv','825cc2.csv','ac20cd.csv','c6585a.csv','fe7f93.csv']
i=1
for name in fnames:
    plotCPUUtilizationSeries(('ec2_cpu_utilization_'+name),("Dataset-"+str(i)))
    i=i+1
